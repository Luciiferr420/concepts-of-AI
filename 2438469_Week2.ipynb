# %% [markdown]
# <a href="https://colab.research.google.com/github/Luciiferr420/concepts-of-AI/blob/main/2438469_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s = pd.Series([32,56,78,67])
s
# Out:
# 0    32
# 1    56
# 2    78
# 3    67
# dtype: int64

# %%
s = pd.Series([34,56,78,59], index = ['a','b','c','d'])
s
# Out:
# a    34
# b    56
# c    78
# d    59
# dtype: int64

# %%
data = {"Name":["Arya","Russ","Subashna","Prasanna"],"Age":[28,25,20,19],"Salary":[28000,25000,20000,19000]}

# %%
df = pd.DataFrame(data)
df.tail(2)
# Out:
#        Name  Age  Salary
# 2  Subashna   20   20000
# 3  Prasanna   19   19000

# %%
df.head(2)
# Out:
#    Name  Age  Salary
# 0  Arya   28   28000
# 1  Russ   25   25000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df["Name"]
# Out:
# 0        Arya
# 1        Russ
# 2    Subashna
# 3    Prasanna
# Name: Name, dtype: object

# %%
df[["Name","Age"]]
# Out:
#        Name  Age
# 0      Arya   28
# 1      Russ   25
# 2  Subashna   20
# 3  Prasanna   19

# %%
df["Address"] = ["ktm","pkr","palpa","chitwan"]

# %%
df
# Out:
#        Name  Age  Salary  Address
# 0      Arya   28   28000      ktm
# 1      Russ   25   25000      pkr
# 2  Subashna   20   20000    palpa
# 3  Prasanna   19   19000  chitwan

# %%
df["New Salary"] = df["Salary"]+0.1*df["Salary"]

# %%
df
# Out:
#        Name  Age  Salary  Address  New Salary
# 0      Arya   28   28000      ktm     30800.0
# 1      Russ   25   25000      pkr     27500.0
# 2  Subashna   20   20000    palpa     22000.0
# 3  Prasanna   19   19000  chitwan     20900.0

# %%
df1 = df.copy()

# %%
df1.drop(columns=["Salary"])
# Out:
#        Name  Age  Address  New Salary
# 0      Arya   28      ktm     30800.0
# 1      Russ   25      pkr     27500.0
# 2  Subashna   20    palpa     22000.0
# 3  Prasanna   19  chitwan     20900.0

# %%
df.iloc[0:4,0:4]
# Out:
#        Name  Age  Salary  Address
# 0      Arya   28   28000      ktm
# 1      Russ   25   25000      pkr
# 2  Subashna   20   20000    palpa
# 3  Prasanna   19   19000  chitwan

# %%
df.loc[df["Age"]>22]
# Out:
#    Name  Age  Salary Address  New Salary
# 0  Arya   28   28000     ktm     30800.0
# 1  Russ   25   25000     pkr     27500.0

# %%
df = pd.read_csv("/content/drive/MyDrive/Concepts and tech of ai/Week 2/Copy of bank.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
